# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.simplefilter('ignore')

# %%
df= pd.read_csv('Churn_Modelling.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.drop(['RowNumber', 'Surname', 'CustomerId'], axis=1, inplace=True)
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df.describe(include='all')
# Out:
#          CreditScore Geography Gender           Age        Tenure  \
# count   10000.000000     10000  10000  10000.000000  10000.000000
# unique           NaN         3      2           NaN           NaN
# top              NaN    France   Male           NaN           NaN
# freq             NaN      5014   5457           NaN           NaN
# mean      650.528800       NaN    NaN     38.921800      5.012800
# std        96.653299       NaN    NaN     10.487806      2.892174
# min       350.000000       NaN    NaN     18.000000      0.000000
# 25%       584.000000       NaN    NaN     32.000000      3.000000
# 50%       652.000000       NaN    NaN     37.000000      5.000000
# 75%       718.000000       NaN    NaN     44.000000      7.000000
# max       850.000000       NaN    NaN     92.000000     10.000000
#
#               Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count    10000.000000   10000.000000  10000.00000    10000.000000
# ...

# %%
def print_unique_values(df):
    for cols in df:
        print(f'{cols} : {df[cols].unique()} ')

# %%
print_unique_values(df)
# Out:
# CreditScore : [619 608 502 699 850 645 822 376 501 684 528 497 476 549 635 616 653 587
#  726 732 636 510 669 846 577 756 571 574 411 591 533 553 520 722 475 490
#  804 582 472 465 556 834 660 776 829 637 550 698 585 788 655 601 656 725
#  511 614 742 687 555 603 751 581 735 661 675 738 813 657 604 519 664 678
#  757 416 665 777 543 506 493 652 750 729 646 647 808 524 769 730 515 773
#  814 710 413 623 670 622 785 605 479 685 538 562 721 628 668 828 674 625
#  432 770 758 795 686 789 589 461 584 579 663 682 793 691 485 650 754 535
#  716 539 706 586 631 717 800 683 704 615 667 484 480 578 512 606 597 778
#  514 525 715 580 807 521 759 516 711 618 643 671 689 620 676 572 695 592
#  567 694 547 594 673 610 767 763 712 703 662 659 523 772 545 634 739 771
#  681 544 696 766 727 693 557 531 498 651 791 733 811 707 714 782 775 799
#  602 744 588 747 583 627 731 629 438 642 806 474 559 429 680 749 734 644
#  626 649 805 718 840 630 654 762 568 613 522 737 648 443 640 540 460 593
# ...

# %%
df_outliers_possibility=df[['CreditScore', 'Age', 'Tenure', 'Balance', 'EstimatedSalary']]
df_outliers_possibility.head()
# Out:
#    CreditScore  Age  Tenure    Balance  EstimatedSalary
# 0          619   42       2       0.00        101348.88
# 1          608   41       1   83807.86        112542.58
# 2          502   42       8  159660.80        113931.57
# 3          699   39       1       0.00         93826.63
# 4          850   43       2  125510.82         79084.10

# %%
def check_outliers(df):
    for cols in df:
        sns.boxplot(data=df[cols] )
        plt.xlabel(f'{cols}')
        plt.show()

# %%
check_outliers(df_outliers_possibility)

# %%
Q1=np.percentile(df['CreditScore'], 25, interpolation='midpoint')
Q3=np.percentile(df['CreditScore'], 75, interpolation='midpoint' )
IQR=Q3-Q1

print('Old Shape : ', df.shape)

upper=np.where(df['CreditScore']>= (Q3 + 1.5*IQR))
lower=np.where(df['CreditScore']<= (Q1 - 1.5*IQR))

df.drop(upper[0], inplace=True)
df.drop(lower[0], inplace=True)

print('New Shape : ', df.shape )
# Out:
# Old Shape :  (10000, 11)
# New Shape :  (9984, 11)

# %%
Q1=np.percentile(df['Age'], 25, interpolation='midpoint')
Q3=np.percentile(df['Age'], 75, interpolation='midpoint' )
IQR=Q3-Q1

print('Old Shape : ', df.shape)

upper=np.where(df['Age']>= (Q3 + 2*IQR))
lower=np.where(df['Age']<= (Q1 - 2*IQR))

df.drop(upper[0], inplace=True)
df.drop(lower[0], inplace=True)

print('New Shape : ', df.shape )
# Out:
# Old Shape :  (9984, 11)
# New Shape :  (9792, 11)

# %%
plt.figure(figsize=(15,8))
sns.histplot(df['CreditScore'], kde=True)
plt.xlabel('Credit Score', fontsize=15)
plt.ylabel('Frequecy', fontsize=15)
plt.title('Credit Score Frequency Distribution', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='CreditScore', y='Age', data=df)
# Out:
# <AxesSubplot:xlabel='CreditScore', ylabel='Age'>

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='EstimatedSalary', y='Age', data=df)
# Out:
# <AxesSubplot:xlabel='EstimatedSalary', ylabel='Age'>

# %%
df[df['Age']>85]
print(df.shape)
df = df.drop(labels=[2458,6443,6759], axis=0)
print(df.shape)
# Out:
# (9792, 11)
# (9789, 11)

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='EstimatedSalary', y='Age', data=df)
# Out:
# <AxesSubplot:xlabel='EstimatedSalary', ylabel='Age'>

# %%
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
df1=pd.get_dummies(data=df, columns=['Geography'], drop_first=True)
df1.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619  Female   42       2       0.00              1          1
# 1          608  Female   41       1   83807.86              1          0
# 2          502  Female   42       8  159660.80              3          1
# 3          699  Female   39       1       0.00              2          0
# 4          850  Female   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  Geography_Spain
# 0               1        101348.88       1                  0                0
# 1               1        112542.58       0                  0                1
# 2               0        113931.57       1                  0                0
# 3               0         93826.63       0                  0                0
# 4               1         79084.10       0                  0                1

# %%
df1['Gender'].replace({'Female': 0,
                          'Male': 1}, inplace=True)
df1.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619       0   42       2       0.00              1          1
# 1          608       0   41       1   83807.86              1          0
# 2          502       0   42       8  159660.80              3          1
# 3          699       0   39       1       0.00              2          0
# 4          850       0   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  Geography_Spain
# 0               1        101348.88       1                  0                0
# 1               1        112542.58       0                  0                1
# 2               0        113931.57       1                  0                0
# 3               0         93826.63       0                  0                0
# 4               1         79084.10       0                  0                1

# %%
cols_to_scale=['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']
from sklearn.preprocessing import MinMaxScaler
scalar=MinMaxScaler()
df1[cols_to_scale]=scalar.fit_transform(df1[cols_to_scale])

# %%
plt.figure(figsize=(15,8))
cm=df1.corr()
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
X=df1.drop('Exited', axis=1)
y=df[['Exited']]
X.shape, y.shape
# Out:
# ((9789, 11), (9789, 1))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train.shape, X_test.shape
# Out:
# ((7831, 11), (1958, 11))

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([
    keras.layers.Dense(10, input_shape=(11,), activation='relu'),
    keras.layers.Dense(10, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid'),    
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.fit(X_train, y_train, epochs=500)
# Out:
# Epoch 1/500
# 245/245 [==============================] - 1s 1ms/step - loss: 0.5665 - accuracy: 0.7710
# Epoch 2/500
# 245/245 [==============================] - 0s 1ms/step - loss: 0.4550 - accuracy: 0.8066
# Epoch 3/500
# 245/245 [==============================] - 0s 1ms/step - loss: 0.4524 - accuracy: 0.8028
# Epoch 4/500
# 245/245 [==============================] - 0s 1ms/step - loss: 0.4380 - accuracy: 0.8122
# Epoch 5/500
# 245/245 [==============================] - 0s 1ms/step - loss: 0.4307 - accuracy: 0.8179
# Epoch 6/500
# 245/245 [==============================] - 0s 1ms/step - loss: 0.4319 - accuracy: 0.8149
# Epoch 7/500
# 245/245 [==============================] - 0s 1ms/step - loss: 0.4169 - accuracy: 0.8280
# Epoch 8/500
# 245/245 [==============================] - 0s 1ms/step - loss: 0.4117 - accuracy: 0.8333
# Epoch 9/500
# 245/245 [==============================] - 0s 1ms/step - loss: 0.4166 - accuracy: 0.8285
# Epoch 10/500
# ...

# %%
model.evaluate(X_test, y_test)
# Out:
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3504 - accuracy: 0.8565
# [0.3504254221916199, 0.8564862012863159]
